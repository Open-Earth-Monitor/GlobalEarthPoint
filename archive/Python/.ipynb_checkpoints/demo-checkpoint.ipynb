# %%
import duckdb
url="https://s3.opengeohub.org/global/glidar/gedi-ard/level2/l2v002.gedi_20190418_20230316_go_epsg.4326_v20240827/lon=-10/lat=20/year=2019/gedi_l2ab.parquet"
df_duckdb = duckdb.sql(f"""
                        INSTALL httpfs;
                        LOAD httpfs;
                        INSTALL spatial;
                        LOAD spatial;

                        SELECT rh95, geometry

                        FROM "{url}"
                        """)

df=df_duckdb.df()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
df
