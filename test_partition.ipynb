# %% [markdown]
# ## test to locate to a random polygon of data through different partition
#
# 1.

# %%
from shapely.geometry import Point, Polygon, MultiPolygon, LineString, box

def geometry_to_1d_tile_indices(geometry):
    # Convert different geometry types to bounding box
    if isinstance(geometry, Point):
        bbox = geometry.buffer(1e-10)  # Buffer by 1 degree for points
    elif isinstance(geometry, LineString):
        bbox = geometry.buffer(1e-10)  # Buffer by 1 degree for lines
    elif isinstance(geometry, (Polygon, MultiPolygon)):
        bbox = geometry  # Bounding box for polygons and multipolygons
    else:
        raise ValueError("Unsupported geometry type")

    # Extract bounding box coordinates
    xmin, ymin, xmax, ymax = bbox.bounds
    lon_indices = range(int(xmin), int(xmax)+1)
    lat_indices = range(int(ymin), int(ymax)+1)
    grid_cells = []
    for lat_indice in lat_indices:
        for lon_indice in lon_indices:
            grid_cells.append(box(lon_indice,lat_indice,lon_indice+1,lat_indice+1))
    print(grid_cells)
    overlapping_cells = [cell for cell in grid_cells if bbox.intersects(cell)]
    tiles = []
    for tile in overlapping_cells:
        x = tile.bounds[0]
        lon = f'{str(int(x)).zfill(3)}E' if x>=0 else f'{str(-int(x)).zfill(3)}W'
        y = tile.bounds[1]
        lat = f'{str(int(y)).zfill(2)}N' if x>=0 else f'{str(-int(y)).zfill(2)}S'
        tiles.append(f"{lon}_{lat}")
    print('number of tile in the bbox:',len(grid_cells))
    print('number of tile overlapping in the polygon:',len(tiles))
    
    return tiles

def geometry_to_3d_tile_indices(geometry):
    # Convert different geometry types to bounding box
    if isinstance(geometry, Point):
        bbox = geometry.buffer(1e-10)  # Buffer by 1 degree for points
    elif isinstance(geometry, LineString):
        bbox = geometry.buffer(1e-10)  # Buffer by 1 degree for lines
    elif isinstance(geometry, (Polygon, MultiPolygon)):
        bbox = geometry  # Bounding box for polygons and multipolygons
    else:
        raise ValueError("Unsupported geometry type")

    # Extract bounding box coordinates
    xmin, ymin, xmax, ymax = bbox.bounds
    lat_indices = range(int(ymin/3)*3, int(ymax/3)*3 + 3, 3)
    lon_indices = range(int(xmin/3)*3, int(xmax/3)*3 + 3, 3)
    grid_cells = []
    for lat_indice in lat_indices:
        for lon_indice in lon_indices:
            grid_cells.append(box(lon_indice,lat_indice,lon_indice+3,lat_indice+3))
    print(grid_cells)
    overlapping_cells = [cell for cell in grid_cells if bbox.intersects(cell)]
    tiles = []
    for tile in overlapping_cells:
        x = tile.bounds[0]
        lon = f'{str(int(x)).zfill(3)}E' if x>=0 else f'{str(-int(x)).zfill(3)}W'
        y = tile.bounds[1]
        lat = f'{str(int(y)).zfill(2)}N' if x>=0 else f'{str(-int(y)).zfill(2)}S'
        tiles.append(f"{lon}_{lat}")
    print('number of tile in the bbox:',len(grid_cells))
    print('number of tile overlapping in the polygon:',len(tiles))
    
    return tiles

def geometry_to_6d_tile_indices(geometry):
    # Convert different geometry types to bounding box
    if isinstance(geometry, Point):
        bbox = geometry.buffer(1e-10)  # Buffer by 1 degree for points
    elif isinstance(geometry, LineString):
        bbox = geometry.buffer(1e-10)  # Buffer by 1 degree for lines
    elif isinstance(geometry, (Polygon, MultiPolygon)):
        bbox = geometry  # Bounding box for polygons and multipolygons
    else:
        raise ValueError("Unsupported geometry type")

    # Extract bounding box coordinates
    xmin, ymin, xmax, ymax = bbox.bounds
    lat_indices = range(int(ymin/6)*6, int(ymax/6)*6 + 6, 6)
    lon_indices = range(int(xmin/6)*6, int(xmax/6)*6 + 6, 6)
    grid_cells = []
    for lat_indice in lat_indices:
        for lon_indice in lon_indices:
            grid_cells.append(box(lon_indice,lat_indice,lon_indice+6,lat_indice+6))
    
    overlapping_cells = [cell for cell in grid_cells if bbox.intersects(cell)]
    
    print(grid_cells)
    tiles = []
    for tile in overlapping_cells:
        x = tile.bounds[0]
        lon = f'{str(int(x)).zfill(3)}E' if x>=0 else f'{str(-int(x)).zfill(3)}W'
        y = tile.bounds[1]
        lat = f'{str(int(y)).zfill(2)}N' if x>=0 else f'{str(-int(y)).zfill(2)}S'
        tiles.append(f"{lon}_{lat}")
    print('number of tile in the bbox:',len(grid_cells))
    print('number of tile overlapping in the polygon:',len(tiles))
    
    return tiles

# %%
from shapely.geometry import shape
from shapely import wkb
import geopandas as gpd

from ipyleaflet import Map, basemaps, basemap_to_tiles, DrawControl, LayersControl
import contextily as cx
# Out:
# /home/opengeohub/.local/lib/python3.8/site-packages/geopandas/_compat.py:124: UserWarning: The Shapely GEOS version (3.11.2-CAPI-1.17.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.2-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(
# /tmp/ipykernel_11847/2756515710.py:3: DeprecationWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas still uses PyGEOS by default. However, starting with version 0.14, the default will switch to Shapely. To force to use Shapely 2.0 now, you can either uninstall PyGEOS or set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In the next release, GeoPandas will switch to using Shapely by default, even if PyGEOS is installed. If you only have PyGEOS installed to get speed-ups, this switch should be smooth. However, if you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd

# %%
mapnik = basemap_to_tiles(basemaps.OpenStreetMap.Mapnik)
mapnik.base = True
mapnik.name = 'Mapnik Layer'

esri = basemap_to_tiles(basemaps.Esri.WorldImagery)
esri.base = True
esri.name = 'ESRI Imagery Layer'

m = Map(center=(10,15), zoom = 8, layers = [esri, mapnik])

draw_control = DrawControl()
draw_control.rectangle = {
    "shapeOptions": {
        "color": "#ff0000",
        "fillOpacity": 0,
        "opacity": 1
    }
}

m.add_control(draw_control)
m.add_control(LayersControl())

m
# Out:
# Map(center=[10, 15], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_tex…

# %%
geometry = shape(draw_control.data[-1]['geometry'])
aoi = gpd.GeoDataFrame({'geometry': [geometry]}, crs='EPSG:4326')
print(aoi.geometry[0])
# Out:
# POLYGON ((12.078256 11.791561, 12.0962 8.552843, 14.884049 8.592347, 12.266069 8.839153, 12.078256 11.791561))

# %% [markdown]
# ## give a random point and buffer out

# %%
import random

# %%
rand_point = Point(random.uniform(12,18),random.uniform(6,12))

# %%
geometry = rand_point.buffer(0.5)
aoi = gpd.GeoDataFrame({'geometry': [geometry]}, crs='EPSG:4326')

# %%
list_of_tile = geometry_to_1d_tile_indices(geometry)
# Out:
# [<POLYGON ((16 8, 16 9, 15 9, 15 8, 16 8))>, <POLYGON ((17 8, 17 9, 16 9, 16 8, 17 8))>, <POLYGON ((16 9, 16 10, 15 10, 15 9, 16 9))>, <POLYGON ((17 9, 17 10, 16 10, 16 9, 17 9))>]
# number of tile in the bbox: 4
# number of tile overlapping in the polygon: 3

# %%
list_of_tile
# Out:
# ['016E_10N', '016E_11N', '017E_10N', '017E_11N']

# %%
list_of_tile = geometry_to_tile_indices(aoi.geometry[0])

# %%
list_of_tile
# Out:
# ['014E_09N', '014E_10N', '015E_09N', '015E_10N']

# %%
import os
import polars as pl

os.environ['USE_PYGEOS'] = '0'
from pyarrow.dataset import dataset,field,parquet_dataset
from s3fs import S3FileSystem
import pyarrow.fs as fs
import pyarrow.parquet as pq
httpfs = S3FileSystem(
      endpoint_url='https://s3.eu-central-1.wasabisys.com',
      anon=True
   )

# %%
## 1 degree_tile
object_path = 'gedi-ard/1degree_tile'
pyarrow_dataset = dataset(
    source = object_path,
    format = 'parquet',
    filesystem=httpfs
)
t = pq.ParquetDataset(path_or_paths=object_path,
                  filesystem=httpfs,
                  filters=[('1degree_tile','in',list_of_tile)])
raw=t.read().to_pandas()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 8>()
#       2 object_path = 'gedi-ard/1degree_tile'
#       3 pyarrow_dataset = dataset(
#       4     source = object_path,
#       5     format = 'parquet',
#       6     filesystem=httpfs
#       7 )
#       8 t = pq.ParquetDataset(path_or_paths=object_path,
#       9                   filesystem=httpfs,
# ---> 10                   filters=[('1degree_tile','in',list_of_tile)])
#      11 raw=t.read().to_pandas()
#
# NameError: name 'list_of_tile' is not defined

# %%
## 1 degree_tile
object_path = 'gedi-ard/1degree_tile'
pyarrow_dataset = dataset(
    source = object_path,
    format = 'parquet',
    filesystem=httpfs
)
t = pq.ParquetDataset(path_or_paths=object_path,
                  filesystem=httpfs,
                  filters=[('1degree_tile','in',list_of_tile)])
raw=t.read().to_pandas()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [18], in <cell line: 3>()
#       1 ## 1 degree_tile
#       2 object_path = 'gedi-ard/1degree_tile'
# ----> 3 pyarrow_dataset = dataset(
#       4     source = object_path,
#       5     format = 'parquet',
#       6     filesystem=httpfs
#       7 )
#       8 t = pq.ParquetDataset(path_or_paths=object_path,
#       9                   filesystem=httpfs,
#      10                   filters=[('1degree_tile','in',list_of_tile)])
#      11 raw=t.read().to_pandas()
#
# File ~/.local/lib/python3.8/site-packages/pyarrow/dataset.py:782, in dataset(source, schema, format, filesystem, partitioning, partition_base_dir, exclude_invalid_files, ignore_prefixes)
#     771 kwargs = dict(
#     772     schema=schema,
#     773     filesystem=filesystem,
#    (...)
#     778     selector_ignore_prefixes=ignore_prefixes
#     779 )
#     781 if _is_path_like(source):
# --> 782     return _filesystem_dataset(source, **kwargs)
#     783 elif isinstance(source, (tuple, list)):
#     784     if all(_is_path_like(elem) for elem in source):
#
# File ~/.local/lib/python3.8/site-packages/pyarrow/dataset.py:475, in _filesystem_dataset(source, schema, filesystem, partitioning, format, partition_base_dir, exclude_invalid_files, selector_ignore_prefixes)
#     467 options = FileSystemFactoryOptions(
#     468     partitioning=partitioning,
#     469     partition_base_dir=partition_base_dir,
#     470     exclude_invalid_files=exclude_invalid_files,
#     471     selector_ignore_prefixes=selector_ignore_prefixes
#     472 )
#     473 factory = FileSystemDatasetFactory(fs, paths_or_selector, format, options)
# --> 475 return factory.finish(schema)
#
# File ~/.local/lib/python3.8/site-packages/pyarrow/_dataset.pyx:3025, in pyarrow._dataset.DatasetFactory.finish()
#
# File ~/.local/lib/python3.8/site-packages/pyarrow/error.pxi:154, in pyarrow.lib.pyarrow_internal_check_status()
#
# File ~/.local/lib/python3.8/site-packages/pyarrow/types.pxi:88, in pyarrow.lib._datatype_to_pep3118()
#
# File ~/.local/lib/python3.8/site-packages/pyarrow/_fs.pyx:1562, in pyarrow._fs._cb_open_input_file()
#
# File ~/.local/lib/python3.8/site-packages/pyarrow/fs.py:432, in FSSpecHandler.open_input_file(self, path)
#     429 from pyarrow import PythonFile
#     431 if not self.fs.isfile(path):
# --> 432     raise FileNotFoundError(path)
#     434 return PythonFile(self.fs.open(path, mode="rb"), mode="r")
#
# FileNotFoundError: gedi-ard/1degree_tile/1degree_tile=012E_06N/9ce08683880349678837228052e94e53-0.parquet

# %%
gdf = gpd.GeoDataFrame(
    raw, geometry=gpd.points_from_xy(raw.longitude, raw.latitude), crs="EPSG:4326"
)

# %%
gdf = gpd.overlay(gdf, aoi, how='intersection')

# %%
t = pq.ParquetDataset(path_or_paths=object_path,
                  filesystem=httpfs,
                  filters=[('1degree_tile','in',list_of_tile)])

# %%
def timer(geometry,partition='1degree_tile'):
    import os
    import polars as pl
    import time
    os.environ['USE_PYGEOS'] = '0'
    from pyarrow.dataset import dataset,field,parquet_dataset
    from s3fs import S3FileSystem
    import pyarrow.fs as fs
    import pyarrow.parquet as pq
    httpfs = S3FileSystem(
          endpoint_url='https://s3.eu-central-1.wasabisys.com',
          anon=True
       )
    if partition == '1degree_tile':
        geometry_to_tile_indices = geometry_to_1d_tile_indices
    elif  partition == '3degree_tile':
        geometry_to_tile_indices = geometry_to_3d_tile_indices
    elif  partition == '6degree_tile':
        geometry_to_tile_indices = geometry_to_6d_tile_indices
    aoi = gpd.GeoDataFrame({'geometry': [geometry]}, crs='EPSG:4326')
    list_of_tile = geometry_to_tile_indices(geometry)
    print(list_of_tile)
    object_path = f'gedi-ard/{partition}'
    pyarrow_dataset = dataset(
        source = object_path,
        format = 'parquet',
        filesystem=httpfs
    )
    start = time.time()
    t = pq.ParquetDataset(path_or_paths=object_path,
                      filesystem=httpfs,
                      filters=[(partition,'in',list_of_tile)])
    raw=t.read().to_pandas()

    print(f"extract points in {time.time() - start:.2f} s", flush=True)
    ext_time = (time.time() - start)
    print(f'number of points extracted: {len(raw)}', flush=True)
    start1 = time.time()
    gdf = gpd.GeoDataFrame(
        raw, geometry=gpd.points_from_xy(raw.longitude, raw.latitude), crs="EPSG:4326"
    )
    #gdf[['latitude','longitude','geometry']].to_file(f'{partition}.gpkg',Driver='GPKG')
    out_gdf = gpd.overlay(gdf, aoi, how='intersection')
    refine_time = (time.time() - start1)
    #print(out_gdf)
    #out_gdf[['latitude','longitude','geometry']].to_file(f'{partition}_cut.gpkg',Driver='GPKG')
    print(f"refine points in {time.time() - start1:.2f} s", flush=True)    
    print(f'number of points refined: {len(out_gdf)}', flush=True)
    print(f"total time in {time.time() - start:.2f} s", flush=True)    
    total_time = (time.time() - start)
    return ext_time, refine_time, total_time

# %%
geometry_to_6d_tile_indices(geometry)
# Out:
# [<POLYGON ((18 6, 18 12, 12 12, 12 6, 18 6))>]
# number of tile in the bbox: 1
# number of tile overlapping in the polygon: 1
# ['012E_06N']

# %%
import random
rand_point = Point(random.uniform(12,18),random.uniform(6,12))
geometry = rand_point.buffer(1)

# %%
timer(geometry,partition='1degree_tile')
# Out:
# [<POLYGON ((17 9, 17 10, 16 10, 16 9, 17 9))>, <POLYGON ((18 9, 18 10, 17 10, 17 9, 18 9))>, <POLYGON ((19 9, 19 10, 18 10, 18 9, 19 9))>, <POLYGON ((17 10, 17 11, 16 11, 16 10, 17 10))>, <POLYGON ((18 10, 18 11, 17 11, 17 10, 18 10))>, <POLYGON ((19 10, 19 11, 18 11, 18 10, 19 10))>, <POLYGON ((17 11, 17 12, 16 12, 16 11, 17 11))>, <POLYGON ((18 11, 18 12, 17 12, 17 11, 18 11))>, <POLYGON ((19 11, 19 12, 18 12, 18 11, 19 11))>]
# number of tile in the bbox: 9
# number of tile overlapping in the polygon: 7
# ['017E_09N', '016E_10N', '017E_10N', '018E_10N', '016E_11N', '017E_11N', '018E_11N']
# extract points in 1.69 s
# number of points extracted: 843099
# refine points in 1.73 s
# number of points refined: 381698
# total time in 3.42 s
# (1.6920669078826904, 1.7263762950897217, 3.4213356971740723)

# %%
timer(geometry,partition='3degree_tile')
# Out:
# [<POLYGON ((15 9, 15 12, 12 12, 12 9, 15 9))>, <POLYGON ((18 9, 18 12, 15 12, 15 9, 18 9))>]
# number of tile in the bbox: 2
# number of tile overlapping in the polygon: 2
# ['012E_09N', '015E_09N']
# extract points in 6.40 s
# number of points extracted: 2531113
# refine points in 2.94 s
# number of points refined: 384455
# total time in 9.35 s

# %%
timer(geometry,partition='6degree_tile')
# Out:
# [<POLYGON ((18 6, 18 12, 12 12, 12 6, 18 6))>]
# number of tile in the bbox: 1
# number of tile overlapping in the polygon: 1
# ['012E_06N']
# extract points in 15.96 s
# number of points extracted: 5441920
# refine points in 5.21 s
# number of points refined: 384455
# total time in 21.18 s

# %%
import random
ext_times_1=[]
refine_times_1=[]
total_times_1=[]
for i in range(30):
    rand_point = Point(random.uniform(12,18),random.uniform(6,12))
    geometry = rand_point.buffer(1)
    ext_time, refine_time, total_time = timer(geometry,partition='1degree_tile')
    ext_times_1.append(ext_time)
    refine_times_1.append(refine_time)
    total_times_1.append(total_time)
# Out:
# [<POLYGON ((15 10, 15 11, 14 11, 14 10, 15 10))>, <POLYGON ((16 10, 16 11, 15 11, 15 10, 16 10))>, <POLYGON ((17 10, 17 11, 16 11, 16 10, 17 10))>, <POLYGON ((15 11, 15 12, 14 12, 14 11, 15 11))>, <POLYGON ((16 11, 16 12, 15 12, 15 11, 16 11))>, <POLYGON ((17 11, 17 12, 16 12, 16 11, 17 11))>, <POLYGON ((15 12, 15 13, 14 13, 14 12, 15 12))>, <POLYGON ((16 12, 16 13, 15 13, 15 12, 16 12))>, <POLYGON ((17 12, 17 13, 16 13, 16 12, 17 12))>]
# number of tile in the bbox: 9
# number of tile overlapping in the polygon: 8
# ['015E_10N', '016E_10N', '014E_11N', '015E_11N', '016E_11N', '014E_12N', '015E_12N', '016E_12N']
# extract points in 2.05 s
# number of points extracted: 713981
# refine points in 1.55 s
# number of points refined: 323895
# total time in 3.61 s
# [<POLYGON ((16 6, 16 7, 15 7, 15 6, 16 6))>, <POLYGON ((17 6, 17 7, 16 7, 16 6, 17 6))>, <POLYGON ((18 6, 18 7, 17 7, 17 6, 18 6))>, <POLYGON ((16 7, 16 8, 15 8, 15 7, 16 7))>, <POLYGON ((17 7, 17 8, 16 8, 16 7, 17 7))>, <POLYGON ((18 7, 18 8, 17 8, 17 7, 18 7))>, <POLYGON ((16 8, 16 9, 15 9, 15 8, 16 8))>, <POLYGON ((17 8, 17 9, 16 9, 16 8, 17 8))>, <POLYGON ((18 8, 18 9, 17 9, 17 8, 18 8))>]
# number of tile in the bbox: 9
# number of tile overlapping in the polygon: 9
# ['015E_06N', '016E_06N', '017E_06N', '015E_07N', '016E_07N', '017E_07N', '015E_08N', '016E_08N', '017E_08N']
# extract points in 2.63 s
# number of points extracted: 1440365
# refine points in 2.89 s
# number of points refined: 493677
# total time in 5.52 s
# [<POLYGON ((17 9, 17 10, 16 10, 16 9, 17 9))>, <POLYGON ((18 9, 18 10, 17 10, 17 9, 18 9))>, <POLYGON ((19 9, 19 10, 18 10, 18 9, 19 9))>, <POLYGON ((17 10, 17 11, 16 11, 16 10, 17 10))>, <POLYGON ((18 10, 18 11, 17 11, 17 10, 18 10))>, <POLYGON ((19 10, 19 11, 18 11, 18 10, 19 10))>, <POLYGON ((17 11, 17 12, 16 12, 16 11, 17 11))>, <POLYGON ((18 11, 18 12, 17 12, 17 11, 18 11))>, <POLYGON ((19 11, 19 12, 18 12, 18 11, 19 11))>]
# number of tile in the bbox: 9
# number of tile overlapping in the polygon: 9
# ['016E_09N', '017E_09N', '018E_09N', '016E_10N', '017E_10N', '018E_10N', '016E_11N', '017E_11N', '018E_11N']
# extract points in 1.85 s
# number of points extracted: 956788
# refine points in 2.39 s
# number of points refined: 463632
# total time in 4.24 s
# [<POLYGON ((17 9, 17 10, 16 10, 16 9, 17 9))>, <POLYGON ((18 9, 18 10, 17 10, 17 9, 18 9))>, <POLYGON ((19 9, 19 10, 18 10, 18 9, 19 9))>, <POLYGON ((17 10, 17 11, 16 11, 16 10, 17 10))>, <POLYGON ((18 10, 18 11, 17 11, 17 10, 18 10))>, <POLYGON ((19 10, 19 11, 18 11, 18 10, 19 10))>, <POLYGON ((17 11, 17 12, 16 12, 16 11, 17 11))>, <POLYGON ((18 11, 18 12, 17 12, 17 11, 18 11))>, <POLYGON ((19 11, 19 12, 18 12, 18 11, 19 11))>]
# number of tile in the bbox: 9
# number of tile overlapping in the polygon: 8
# ['016E_09N', '017E_09N', '016E_10N', '017E_10N', '018E_10N', '016E_11N', '017E_11N', '018E_11N']
# extract points in 1.82 s
# number of points extracted: 956788
# refine points in 2.35 s
# number of points refined: 515100
# total time in 4.18 s
# [<POLYGON ((14 7, 14 8, 13 8, 13 7, 14 7))>, <POLYGON ((15 7, 15 8, 14 8, 14 7, 15 7))>, <POLYGON ((16 7, 16 8, 15 8, 15 7, 16 7))>, <POLYGON ((14 8, 14 9, 13 9, 13 8, 14 8))>, <POLYGON ((15 8, 15 9, 14 9, 14 8, 15 8))>, <POLYGON ((16 8, 16 9, 15 9, 15 8, 16 8))>, <POLYGON ((14 9, 14 10, 13 10, 13 9, 14 9))>, <POLYGON ((15 9, 15 10, 14 10, 14 9, 15 9))>, <POLYGON ((16 9, 16 10, 15 10, 15 9, 16 9))>]
# number of tile in the bbox: 9
# number of tile overlapping in the polygon: 9
# ['013E_07N', '014E_07N', '015E_07N', '013E_08N', '014E_08N', '015E_08N', '013E_09N', '014E_09N', '015E_09N']
# extract points in 3.15 s
# number of points extracted: 1306684
# refine points in 2.29 s
# number of points refined: 410417
# total time in 5.45 s
# [<POLYGON ((14 5, 14 6, 13 6, 13 5, 14 5))>, <POLYGON ((15 5, 15 6, 14 6, 14 5, 15 5))>, <POLYGON ((16 5, 16 6, 15 6, 15 5, 16 5))>, <POLYGON ((14 6, 14 7, 13 7, 13 6, 14 6))>, <POLYGON ((15 6, 15 7, 14 7, 14 6, 15 6))>, <POLYGON ((16 6, 16 7, 15 7, 15 6, 16 6))>, <POLYGON ((14 7, 14 8, 13 8, 13 7, 14 7))>, <POLYGON ((15 7, 15 8, 14 8, 14 7, 15 7))>, <POLYGON ((16 7, 16 8, 15 8, 15 7, 16 7))>]
# number of tile in the bbox: 9
# number of tile overlapping in the polygon: 8
# ['013E_05N', '014E_05N', '015E_05N', '013E_06N', '014E_06N', '015E_06N', '013E_07N', '014E_07N']
# extract points in 1.93 s
# number of points extracted: 1001076
# refine points in 2.18 s
# number of points refined: 450440
# total time in 4.11 s
# [<POLYGON ((12 7, 12 8, 11 8, 11 7, 12 7))>, <POLYGON ((13 7, 13 8, 12 8, 12 7, 13 7))>, <POLYGON ((14 7, 14 8, 13 8, 13 7, 14 7))>, <POLYGON ((12 8, 12 9, 11 9, 11 8, 12 8))>, <POLYGON ((13 8, 13 9, 12 9, 12 8, 13 8))>, <POLYGON ((14 8, 14 9, 13 9, 13 8, 14 8))>, <POLYGON ((12 9, 12 10, 11 10, 11 9, 12 9))>, <POLYGON ((13 9, 13 10, 12 10, 12 9, 13 9))>, <POLYGON ((14 9, 14 10, 13 10, 13 9, 14 9))>]
# number of tile in the bbox: 9
# number of tile overlapping in the polygon: 9
# ['011E_07N', '012E_07N', '013E_07N', '011E_08N', '012E_08N', '013E_08N', '011E_09N', '012E_09N', '013E_09N']
# extract points in 1.57 s
# number of points extracted: 894026
# refine points in 1.58 s
# number of points refined: 310092
# total time in 3.15 s
# [<POLYGON ((13 6, 13 7, 12 7, 12 6, 13 6))>, <POLYGON ((14 6, 14 7, 13 7, 13 6, 14 6))>, <POLYGON ((15 6, 15 7, 14 7, 14 6, 15 6))>, <POLYGON ((13 7, 13 8, 12 8, 12 7, 13 7))>, <POLYGON ((14 7, 14 8, 13 8, 13 7, 14 7))>, <POLYGON ((15 7, 15 8, 14 8, 14 7, 15 7))>, <POLYGON ((13 8, 13 9, 12 9, 12 8, 13 8))>, <POLYGON ((14 8, 14 9, 13 9, 13 8, 14 8))>, <POLYGON ((15 8, 15 9, 14 9, 14 8, 15 8))>]
# number of tile in the bbox: 9
# number of tile overlapping in the polygon: 9
# ['012E_06N', '013E_06N', '014E_06N', '012E_07N', '013E_07N', '014E_07N', '012E_08N', '013E_08N', '014E_08N']
# extract points in 3.41 s
# number of points extracted: 1470442
# refine points in 2.78 s
# number of points refined: 543423
# total time in 6.19 s
# [<POLYGON ((12 9, 12 10, 11 10, 11 9, 12 9))>, <POLYGON ((13 9, 13 10, 12 10, 12 9, 13 9))>, <POLYGON ((14 9, 14 10, 13 10, 13 9, 14 9))>, <POLYGON ((12 10, 12 11, 11 11, 11 10, 12 10))>, <POLYGON ((13 10, 13 11, 12 11, 12 10, 13 10))>, <POLYGON ((14 10, 14 11, 13 11, 13 10, 14 10))>, <POLYGON ((12 11, 12 12, 11 12, 11 11, 12 11))>, <POLYGON ((13 11, 13 12, 12 12, 12 11, 13 11))>, <POLYGON ((14 11, 14 12, 13 12, 13 11, 14 11))>]
# number of tile in the bbox: 9
# number of tile overlapping in the polygon: 8
# ['011E_09N', '012E_09N', '013E_09N', '011E_10N', '012E_10N', '013E_10N', '012E_11N', '013E_11N']
# extract points in 2.98 s
# number of points extracted: 814346
# refine points in 1.99 s
# number of points refined: 423472
# total time in 4.98 s
# [<POLYGON ((12 6, 12 7, 11 7, 11 6, 12 6))>, <POLYGON ((13 6, 13 7, 12 7, 12 6, 13 6))>, <POLYGON ((14 6, 14 7, 13 7, 13 6, 14 6))>, <POLYGON ((12 7, 12 8, 11 8, 11 7, 12 7))>, <POLYGON ((13 7, 13 8, 12 8, 12 7, 13 7))>, <POLYGON ((14 7, 14 8, 13 8, 13 7, 14 7))>, <POLYGON ((12 8, 12 9, 11 9, 11 8, 12 8))>, <POLYGON ((13 8, 13 9, 12 9, 12 8, 13 8))>, <POLYGON ((14 8, 14 9, 13 9, 13 8, 14 8))>]
# number of tile in the bbox: 9
# number of tile overlapping in the polygon: 8
# ['012E_06N', '013E_06N', '011E_07N', '012E_07N', '013E_07N', '011E_08N', '012E_08N', '013E_08N']
# extract points in 1.92 s
# number of points extracted: 901775
# refine points in 2.17 s
# number of points refined: 483469
# total time in 4.10 s
# [<POLYGON ((12 6, 12 7, 11 7, 11 6, 12 6))>, <POLYGON ((13 6, 13 7, 12 7, 12 6, 13 6))>, <POLYGON ((14 6, 14 7, 13 7, 13 6, 14 6))>, <POLYGON ((12 7, 12 8, 11 8, 11 7, 12 7))>, <POLYGON ((13 7, 13 8, 12 8, 12 7, 13 7))>, <POLYGON ((14 7, 14 8, 13 8, 13 7, 14 7))>, <POLYGON ((12 8, 12 9, 11 9, 11 8, 12 8))>, <POLYGON ((13 8, 13 9, 12 9, 12 8, 13 8))>, <POLYGON ((14 8, 14 9, 13 9, 13 8, 14 8))>]
# number of tile in the bbox: 9
# number of tile overlapping in the polygon: 7
# ['011E_06N', '012E_06N', '011E_07N', '012E_07N', '013E_07N', '011E_08N', '012E_08N']
# extract points in 1.88 s
# number of points extracted: 596208
# refine points in 1.20 s
# number of points refined: 242682
# total time in 3.08 s
# [<POLYGON ((12 8, 12 9, 11 9, 11 8, 12 8))>, <POLYGON ((13 8, 13 9, 12 9, 12 8, 13 8))>, <POLYGON ((14 8, 14 9, 13 9, 13 8, 14 8))>, <POLYGON ((12 9, 12 10, 11 10, 11 9, 12 9))>, <POLYGON ((13 9, 13 10, 12 10, 12 9, 13 9))>, <POLYGON ((14 9, 14 10, 13 10, 13 9, 14 9))>, <POLYGON ((12 10, 12 11, 11 11, 11 10, 12 10))>, <POLYGON ((13 10, 13 11, 12 11, 12 10, 13 10))>, <POLYGON ((14 10, 14 11, 13 11, 13 10, 14 10))>]
# number of tile in the bbox: 9
# number of tile overlapping in the polygon: 8
# ['011E_08N', '012E_08N', '013E_08N', '011E_09N', '012E_09N', '013E_09N', '012E_10N', '013E_10N']
# extract points in 1.61 s
# number of points extracted: 822109
# refine points in 2.17 s
# number of points refined: 441091
# total time in 3.78 s
# [<POLYGON ((13 9, 13 10, 12 10, 12 9, 13 9))>, <POLYGON ((14 9, 14 10, 13 10, 13 9, 14 9))>, <POLYGON ((15 9, 15 10, 14 10, 14 9, 15 9))>, <POLYGON ((13 10, 13 11, 12 11, 12 10, 13 10))>, <POLYGON ((14 10, 14 11, 13 11, 13 10, 14 10))>, <POLYGON ((15 10, 15 11, 14 11, 14 10, 15 10))>, <POLYGON ((13 11, 13 12, 12 12, 12 11, 13 11))>, <POLYGON ((14 11, 14 12, 13 12, 13 11, 14 11))>, <POLYGON ((15 11, 15 12, 14 12, 14 11, 15 11))>]
# number of tile in the bbox: 9
# number of tile overlapping in the polygon: 8
# ['012E_09N', '013E_09N', '014E_09N', '012E_10N', '013E_10N', '014E_10N', '013E_11N', '014E_11N']
# extract points in 2.18 s
# number of points extracted: 995170
# refine points in 1.91 s
# number of points refined: 372657
# total time in 4.10 s
# [<POLYGON ((15 5, 15 6, 14 6, 14 5, 15 5))>, <POLYGON ((16 5, 16 6, 15 6, 15 5, 16 5))>, <POLYGON ((17 5, 17 6, 16 6, 16 5, 17 5))>, <POLYGON ((15 6, 15 7, 14 7, 14 6, 15 6))>, <POLYGON ((16 6, 16 7, 15 7, 15 6, 16 6))>, <POLYGON ((17 6, 17 7, 16 7, 16 6, 17 6))>, <POLYGON ((15 7, 15 8, 14 8, 14 7, 15 7))>, <POLYGON ((16 7, 16 8, 15 8, 15 7, 16 7))>, <POLYGON ((17 7, 17 8, 16 8, 16 7, 17 7))>]
# number of tile in the bbox: 9
# number of tile overlapping in the polygon: 7
# ['014E_05N', '015E_05N', '014E_06N', '015E_06N', '016E_06N', '014E_07N', '015E_07N']
# extract points in 1.91 s
# number of points extracted: 1051964
# refine points in 2.82 s
# number of points refined: 629947
# total time in 4.73 s
# [<POLYGON ((17 7, 17 8, 16 8, 16 7, 17 7))>, <POLYGON ((18 7, 18 8, 17 8, 17 7, 18 7))>, <POLYGON ((19 7, 19 8, 18 8, 18 7, 19 7))>, <POLYGON ((17 8, 17 9, 16 9, 16 8, 17 8))>, <POLYGON ((18 8, 18 9, 17 9, 17 8, 18 8))>, <POLYGON ((19 8, 19 9, 18 9, 18 8, 19 8))>, <POLYGON ((17 9, 17 10, 16 10, 16 9, 17 9))>, <POLYGON ((18 9, 18 10, 17 10, 17 9, 18 9))>, <POLYGON ((19 9, 19 10, 18 10, 18 9, 19 9))>]
# number of tile in the bbox: 9
# number of tile overlapping in the polygon: 8
# ['017E_07N', '018E_07N', '016E_08N', '017E_08N', '018E_08N', '016E_09N', '017E_09N', '018E_09N']
# extract points in 1.47 s
# number of points extracted: 766715
# refine points in 1.46 s
# number of points refined: 294256
# total time in 2.94 s
# [<POLYGON ((17 10, 17 11, 16 11, 16 10, 17 10))>, <POLYGON ((18 10, 18 11, 17 11, 17 10, 18 10))>, <POLYGON ((19 10, 19 11, 18 11, 18 10, 19 10))>, <POLYGON ((17 11, 17 12, 16 12, 16 11, 17 11))>, <POLYGON ((18 11, 18 12, 17 12, 17 11, 18 11))>, <POLYGON ((19 11, 19 12, 18 12, 18 11, 19 11))>, <POLYGON ((17 12, 17 13, 16 13, 16 12, 17 12))>, <POLYGON ((18 12, 18 13, 17 13, 17 12, 18 12))>, <POLYGON ((19 12, 19 13, 18 13, 18 12, 19 12))>]
# number of tile in the bbox: 9
# number of tile overlapping in the polygon: 8
# ['017E_10N', '018E_10N', '016E_11N', '017E_11N', '018E_11N', '016E_12N', '017E_12N', '018E_12N']
# extract points in 1.21 s
# number of points extracted: 503692
# refine points in 0.96 s
# number of points refined: 177977
# total time in 2.17 s
# [<POLYGON ((13 7, 13 8, 12 8, 12 7, 13 7))>, <POLYGON ((14 7, 14 8, 13 8, 13 7, 14 7))>, <POLYGON ((15 7, 15 8, 14 8, 14 7, 15 7))>, <POLYGON ((13 8, 13 9, 12 9, 12 8, 13 8))>, <POLYGON ((14 8, 14 9, 13 9, 13 8, 14 8))>, <POLYGON ((15 8, 15 9, 14 9, 14 8, 15 8))>, <POLYGON ((13 9, 13 10, 12 10, 12 9, 13 9))>, <POLYGON ((14 9, 14 10, 13 10, 13 9, 14 9))>, <POLYGON ((15 9, 15 10, 14 10, 14 9, 15 9))>]
# number of tile in the bbox: 9
# number of tile overlapping in the polygon: 9
# ['012E_07N', '013E_07N', '014E_07N', '012E_08N', '013E_08N', '014E_08N', '012E_09N', '013E_09N', '014E_09N']
# extract points in 2.67 s
# number of points extracted: 1317485
# refine points in 2.35 s
# number of points refined: 458567
# total time in 5.02 s
# [<POLYGON ((16 9, 16 10, 15 10, 15 9, 16 9))>, <POLYGON ((17 9, 17 10, 16 10, 16 9, 17 9))>, <POLYGON ((18 9, 18 10, 17 10, 17 9, 18 9))>, <POLYGON ((16 10, 16 11, 15 11, 15 10, 16 10))>, <POLYGON ((17 10, 17 11, 16 11, 16 10, 17 10))>, <POLYGON ((18 10, 18 11, 17 11, 17 10, 18 10))>, <POLYGON ((16 11, 16 12, 15 12, 15 11, 16 11))>, <POLYGON ((17 11, 17 12, 16 12, 16 11, 17 11))>, <POLYGON ((18 11, 18 12, 17 12, 17 11, 18 11))>]
# number of tile in the bbox: 9
# number of tile overlapping in the polygon: 8
# ['015E_09N', '016E_09N', '015E_10N', '016E_10N', '017E_10N', '015E_11N', '016E_11N', '017E_11N']
# extract points in 2.02 s
# number of points extracted: 1169210
# refine points in 2.64 s
# number of points refined: 497023
# total time in 4.66 s
# [<POLYGON ((13 6, 13 7, 12 7, 12 6, 13 6))>, <POLYGON ((14 6, 14 7, 13 7, 13 6, 14 6))>, <POLYGON ((15 6, 15 7, 14 7, 14 6, 15 6))>, <POLYGON ((13 7, 13 8, 12 8, 12 7, 13 7))>, <POLYGON ((14 7, 14 8, 13 8, 13 7, 14 7))>, <POLYGON ((15 7, 15 8, 14 8, 14 7, 15 7))>, <POLYGON ((13 8, 13 9, 12 9, 12 8, 13 8))>, <POLYGON ((14 8, 14 9, 13 9, 13 8, 14 8))>, <POLYGON ((15 8, 15 9, 14 9, 14 8, 15 8))>]
# number of tile in the bbox: 9
# number of tile overlapping in the polygon: 9
# ['012E_06N', '013E_06N', '014E_06N', '012E_07N', '013E_07N', '014E_07N', '012E_08N', '013E_08N', '014E_08N']
# extract points in 2.53 s
# number of points extracted: 1470442
# refine points in 2.66 s
# number of points refined: 535827
# total time in 5.19 s
# [<POLYGON ((17 8, 17 9, 16 9, 16 8, 17 8))>, <POLYGON ((18 8, 18 9, 17 9, 17 8, 18 8))>, <POLYGON ((19 8, 19 9, 18 9, 18 8, 19 8))>, <POLYGON ((17 9, 17 10, 16 10, 16 9, 17 9))>, <POLYGON ((18 9, 18 10, 17 10, 17 9, 18 9))>, <POLYGON ((19 9, 19 10, 18 10, 18 9, 19 9))>, <POLYGON ((17 10, 17 11, 16 11, 16 10, 17 10))>, <POLYGON ((18 10, 18 11, 17 11, 17 10, 18 10))>, <POLYGON ((19 10, 19 11, 18 11, 18 10, 19 10))>]
# number of tile in the bbox: 9
# number of tile overlapping in the polygon: 8
# ['017E_08N', '018E_08N', '016E_09N', '017E_09N', '018E_09N', '016E_10N', '017E_10N', '018E_10N']
# extract points in 1.38 s
# number of points extracted: 777101
# refine points in 1.76 s
# number of points refined: 373251
# total time in 3.14 s
# [<POLYGON ((14 8, 14 9, 13 9, 13 8, 14 8))>, <POLYGON ((15 8, 15 9, 14 9, 14 8, 15 8))>, <POLYGON ((16 8, 16 9, 15 9, 15 8, 16 8))>, <POLYGON ((14 9, 14 10, 13 10, 13 9, 14 9))>, <POLYGON ((15 9, 15 10, 14 10, 14 9, 15 9))>, <POLYGON ((16 9, 16 10, 15 10, 15 9, 16 9))>, <POLYGON ((14 10, 14 11, 13 11, 13 10, 14 10))>, <POLYGON ((15 10, 15 11, 14 11, 14 10, 15 10))>, <POLYGON ((16 10, 16 11, 15 11, 15 10, 16 10))>]
# number of tile in the bbox: 9
# number of tile overlapping in the polygon: 8
# ['013E_08N', '014E_08N', '013E_09N', '014E_09N', '015E_09N', '013E_10N', '014E_10N', '015E_10N']
# extract points in 1.84 s
# number of points extracted: 967715
# refine points in 1.97 s
# number of points refined: 392026
# total time in 3.80 s
# [<POLYGON ((16 8, 16 9, 15 9, 15 8, 16 8))>, <POLYGON ((17 8, 17 9, 16 9, 16 8, 17 8))>, <POLYGON ((18 8, 18 9, 17 9, 17 8, 18 8))>, <POLYGON ((16 9, 16 10, 15 10, 15 9, 16 9))>, <POLYGON ((17 9, 17 10, 16 10, 16 9, 17 9))>, <POLYGON ((18 9, 18 10, 17 10, 17 9, 18 9))>, <POLYGON ((16 10, 16 11, 15 11, 15 10, 16 10))>, <POLYGON ((17 10, 17 11, 16 11, 16 10, 17 10))>, <POLYGON ((18 10, 18 11, 17 11, 17 10, 18 10))>]
# number of tile in the bbox: 9
# number of tile overlapping in the polygon: 8
# ['015E_08N', '016E_08N', '017E_08N', '015E_09N', '016E_09N', '017E_09N', '015E_10N', '016E_10N']
# extract points in 2.10 s
# number of points extracted: 1087549
# refine points in 1.99 s
# number of points refined: 359275
# total time in 4.09 s
# [<POLYGON ((16 10, 16 11, 15 11, 15 10, 16 10))>, <POLYGON ((17 10, 17 11, 16 11, 16 10, 17 10))>, <POLYGON ((18 10, 18 11, 17 11, 17 10, 18 10))>, <POLYGON ((16 11, 16 12, 15 12, 15 11, 16 11))>, <POLYGON ((17 11, 17 12, 16 12, 16 11, 17 11))>, <POLYGON ((18 11, 18 12, 17 12, 17 11, 18 11))>, <POLYGON ((16 12, 16 13, 15 13, 15 12, 16 12))>, <POLYGON ((17 12, 17 13, 16 13, 16 12, 17 12))>, <POLYGON ((18 12, 18 13, 17 13, 17 12, 18 12))>]
# number of tile in the bbox: 9
# number of tile overlapping in the polygon: 8
# ['016E_10N', '017E_10N', '015E_11N', '016E_11N', '017E_11N', '015E_12N', '016E_12N', '017E_12N']
# extract points in 1.62 s
# number of points extracted: 828239
# refine points in 1.56 s
# number of points refined: 290216
# total time in 3.18 s
# [<POLYGON ((16 5, 16 6, 15 6, 15 5, 16 5))>, <POLYGON ((17 5, 17 6, 16 6, 16 5, 17 5))>, <POLYGON ((18 5, 18 6, 17 6, 17 5, 18 5))>, <POLYGON ((16 6, 16 7, 15 7, 15 6, 16 6))>, <POLYGON ((17 6, 17 7, 16 7, 16 6, 17 6))>, <POLYGON ((18 6, 18 7, 17 7, 17 6, 18 6))>, <POLYGON ((16 7, 16 8, 15 8, 15 7, 16 7))>, <POLYGON ((17 7, 17 8, 16 8, 16 7, 17 7))>, <POLYGON ((18 7, 18 8, 17 8, 17 7, 18 7))>]
# number of tile in the bbox: 9
# number of tile overlapping in the polygon: 7
# ['015E_05N', '016E_05N', '017E_05N', '015E_06N', '016E_06N', '017E_06N', '016E_07N']
# extract points in 1.40 s
# number of points extracted: 659401
# refine points in 1.34 s
# number of points refined: 260164
# total time in 2.74 s
# [<POLYGON ((12 8, 12 9, 11 9, 11 8, 12 8))>, <POLYGON ((13 8, 13 9, 12 9, 12 8, 13 8))>, <POLYGON ((14 8, 14 9, 13 9, 13 8, 14 8))>, <POLYGON ((12 9, 12 10, 11 10, 11 9, 12 9))>, <POLYGON ((13 9, 13 10, 12 10, 12 9, 13 9))>, <POLYGON ((14 9, 14 10, 13 10, 13 9, 14 9))>, <POLYGON ((12 10, 12 11, 11 11, 11 10, 12 10))>, <POLYGON ((13 10, 13 11, 12 11, 12 10, 13 10))>, <POLYGON ((14 10, 14 11, 13 11, 13 10, 14 10))>]
# number of tile in the bbox: 9
# number of tile overlapping in the polygon: 7
# ['011E_08N', '012E_08N', '013E_08N', '011E_09N', '012E_09N', '013E_09N', '012E_10N']
# extract points in 1.44 s
# number of points extracted: 707010
# refine points in 1.63 s
# number of points refined: 357366
# total time in 3.07 s
# [<POLYGON ((15 8, 15 9, 14 9, 14 8, 15 8))>, <POLYGON ((16 8, 16 9, 15 9, 15 8, 16 8))>, <POLYGON ((17 8, 17 9, 16 9, 16 8, 17 8))>, <POLYGON ((15 9, 15 10, 14 10, 14 9, 15 9))>, <POLYGON ((16 9, 16 10, 15 10, 15 9, 16 9))>, <POLYGON ((17 9, 17 10, 16 10, 16 9, 17 9))>, <POLYGON ((15 10, 15 11, 14 11, 14 10, 15 10))>, <POLYGON ((16 10, 16 11, 15 11, 15 10, 16 10))>, <POLYGON ((17 10, 17 11, 16 11, 16 10, 17 10))>]
# number of tile in the bbox: 9
# number of tile overlapping in the polygon: 9
# ['014E_08N', '015E_08N', '016E_08N', '014E_09N', '015E_09N', '016E_09N', '014E_10N', '015E_10N', '016E_10N']
# extract points in 2.04 s
# number of points extracted: 1095379
# refine points in 1.76 s
# number of points refined: 319820
# total time in 3.80 s
# [<POLYGON ((17 9, 17 10, 16 10, 16 9, 17 9))>, <POLYGON ((18 9, 18 10, 17 10, 17 9, 18 9))>, <POLYGON ((19 9, 19 10, 18 10, 18 9, 19 9))>, <POLYGON ((17 10, 17 11, 16 11, 16 10, 17 10))>, <POLYGON ((18 10, 18 11, 17 11, 17 10, 18 10))>, <POLYGON ((19 10, 19 11, 18 11, 18 10, 19 10))>, <POLYGON ((17 11, 17 12, 16 12, 16 11, 17 11))>, <POLYGON ((18 11, 18 12, 17 12, 17 11, 18 11))>, <POLYGON ((19 11, 19 12, 18 12, 18 11, 19 11))>]
# number of tile in the bbox: 9
# number of tile overlapping in the polygon: 9
# ['016E_09N', '017E_09N', '018E_09N', '016E_10N', '017E_10N', '018E_10N', '016E_11N', '017E_11N', '018E_11N']
# extract points in 1.82 s
# number of points extracted: 956788
# refine points in 2.04 s
# number of points refined: 423413
# total time in 3.86 s
# [<POLYGON ((12 6, 12 7, 11 7, 11 6, 12 6))>, <POLYGON ((13 6, 13 7, 12 7, 12 6, 13 6))>, <POLYGON ((14 6, 14 7, 13 7, 13 6, 14 6))>, <POLYGON ((12 7, 12 8, 11 8, 11 7, 12 7))>, <POLYGON ((13 7, 13 8, 12 8, 12 7, 13 7))>, <POLYGON ((14 7, 14 8, 13 8, 13 7, 14 7))>, <POLYGON ((12 8, 12 9, 11 9, 11 8, 12 8))>, <POLYGON ((13 8, 13 9, 12 9, 12 8, 13 8))>, <POLYGON ((14 8, 14 9, 13 9, 13 8, 14 8))>]
# number of tile in the bbox: 9
# number of tile overlapping in the polygon: 7
# ['011E_06N', '012E_06N', '011E_07N', '012E_07N', '013E_07N', '011E_08N', '012E_08N']
# extract points in 1.36 s
# number of points extracted: 596208
# refine points in 1.20 s
# number of points refined: 247736
# total time in 2.56 s
# [<POLYGON ((15 9, 15 10, 14 10, 14 9, 15 9))>, <POLYGON ((16 9, 16 10, 15 10, 15 9, 16 9))>, <POLYGON ((17 9, 17 10, 16 10, 16 9, 17 9))>, <POLYGON ((15 10, 15 11, 14 11, 14 10, 15 10))>, <POLYGON ((16 10, 16 11, 15 11, 15 10, 16 10))>, <POLYGON ((17 10, 17 11, 16 11, 16 10, 17 10))>, <POLYGON ((15 11, 15 12, 14 12, 14 11, 15 11))>, <POLYGON ((16 11, 16 12, 15 12, 15 11, 16 11))>, <POLYGON ((17 11, 17 12, 16 12, 16 11, 17 11))>]
# number of tile in the bbox: 9
# number of tile overlapping in the polygon: 8
# ['015E_09N', '016E_09N', '014E_10N', '015E_10N', '016E_10N', '014E_11N', '015E_11N', '016E_11N']
# extract points in 1.99 s
# number of points extracted: 1069774
# refine points in 2.03 s
# number of points refined: 404437
# total time in 4.03 s
# [<POLYGON ((12 5, 12 6, 11 6, 11 5, 12 5))>, <POLYGON ((13 5, 13 6, 12 6, 12 5, 13 5))>, <POLYGON ((14 5, 14 6, 13 6, 13 5, 14 5))>, <POLYGON ((12 6, 12 7, 11 7, 11 6, 12 6))>, <POLYGON ((13 6, 13 7, 12 7, 12 6, 13 6))>, <POLYGON ((14 6, 14 7, 13 7, 13 6, 14 6))>, <POLYGON ((12 7, 12 8, 11 8, 11 7, 12 7))>, <POLYGON ((13 7, 13 8, 12 8, 12 7, 13 7))>, <POLYGON ((14 7, 14 8, 13 8, 13 7, 14 7))>]
# number of tile in the bbox: 9
# number of tile overlapping in the polygon: 8
# ['012E_05N', '013E_05N', '011E_06N', '012E_06N', '013E_06N', '011E_07N', '012E_07N', '013E_07N']
# extract points in 1.25 s
# number of points extracted: 629325
# refine points in 1.69 s
# number of points refined: 364645
# total time in 2.95 s

# %%
ext_times_3=[]
refine_times_3=[]
total_times_3=[]
for i in range(30):
    rand_point = Point(random.uniform(12,18),random.uniform(6,12))
    geometry = rand_point.buffer(1)
    ext_time, refine_time, total_time = timer(geometry,partition='3degree_tile')
    ext_times_3.append(ext_time)
    refine_times_3.append(refine_time)
    total_times_3.append(total_time)
# Out:
# [<POLYGON ((12 6, 12 9, 9 9, 9 6, 12 6))>, <POLYGON ((15 6, 15 9, 12 9, 12 6, 15 6))>, <POLYGON ((12 9, 12 12, 9 12, 9 9, 12 9))>, <POLYGON ((15 9, 15 12, 12 12, 12 9, 15 9))>]
# number of tile in the bbox: 4
# number of tile overlapping in the polygon: 4
# ['009E_06N', '012E_06N', '009E_09N', '012E_09N']
# extract points in 5.18 s
# number of points extracted: 2632978
# refine points in 2.73 s
# number of points refined: 295050
# total time in 7.91 s
# [<POLYGON ((15 9, 15 12, 12 12, 12 9, 15 9))>]
# number of tile in the bbox: 1
# number of tile overlapping in the polygon: 1
# ['012E_09N']
# extract points in 4.10 s
# number of points extracted: 1162536
# refine points in 1.90 s
# number of points refined: 350914
# total time in 6.01 s
# [<POLYGON ((12 3, 12 6, 9 6, 9 3, 12 3))>, <POLYGON ((15 3, 15 6, 12 6, 12 3, 15 3))>, <POLYGON ((12 6, 12 9, 9 9, 9 6, 12 6))>, <POLYGON ((15 6, 15 9, 12 9, 12 6, 15 6))>]
# number of tile in the bbox: 4
# number of tile overlapping in the polygon: 4
# ['009E_03N', '012E_03N', '009E_06N', '012E_06N']
# extract points in 3.78 s
# number of points extracted: 1470442
# refine points in 1.39 s
# number of points refined: 160244
# total time in 5.17 s
# [<POLYGON ((18 9, 18 12, 15 12, 15 9, 18 9))>]
# number of tile in the bbox: 1
# number of tile overlapping in the polygon: 1
# ['015E_09N']
# extract points in 3.40 s
# number of points extracted: 1368577
# refine points in 2.41 s
# number of points refined: 472528
# total time in 5.82 s
# [<POLYGON ((18 6, 18 9, 15 9, 15 6, 18 6))>, <POLYGON ((18 9, 18 12, 15 12, 15 9, 18 9))>]
# number of tile in the bbox: 2
# number of tile overlapping in the polygon: 2
# ['015E_06N', '015E_09N']
# extract points in 6.43 s
# number of points extracted: 2808942
# refine points in 3.50 s
# number of points refined: 456484
# total time in 9.94 s
# [<POLYGON ((15 3, 15 6, 12 6, 12 3, 15 3))>, <POLYGON ((18 3, 18 6, 15 6, 15 3, 18 3))>, <POLYGON ((15 6, 15 9, 12 9, 12 6, 15 6))>, <POLYGON ((18 6, 18 9, 15 9, 15 6, 18 6))>]
# number of tile in the bbox: 4
# number of tile overlapping in the polygon: 4
# ['012E_03N', '015E_03N', '012E_06N', '015E_06N']
# extract points in 7.04 s
# number of points extracted: 2910807
# refine points in 3.53 s
# number of points refined: 452423
# total time in 10.57 s
# [<POLYGON ((18 3, 18 6, 15 6, 15 3, 18 3))>, <POLYGON ((18 6, 18 9, 15 9, 15 6, 18 6))>]
# number of tile in the bbox: 2
# number of tile overlapping in the polygon: 2
# ['015E_03N', '015E_06N']
# extract points in 3.70 s
# number of points extracted: 1440365
# refine points in 2.41 s
# number of points refined: 451740
# total time in 6.11 s
# [<POLYGON ((15 3, 15 6, 12 6, 12 3, 15 3))>, <POLYGON ((15 6, 15 9, 12 9, 12 6, 15 6))>]
# number of tile in the bbox: 2
# number of tile overlapping in the polygon: 2
# ['012E_03N', '012E_06N']
# extract points in 4.58 s
# number of points extracted: 1470442
# refine points in 2.36 s
# number of points refined: 454304
# total time in 6.94 s
# [<POLYGON ((15 6, 15 9, 12 9, 12 6, 15 6))>, <POLYGON ((15 9, 15 12, 12 12, 12 9, 15 9))>]
# number of tile in the bbox: 2
# number of tile overlapping in the polygon: 2
# ['012E_06N', '012E_09N']
# extract points in 5.49 s
# number of points extracted: 2632978
# refine points in 3.23 s
# number of points refined: 414352
# total time in 8.73 s
# [<POLYGON ((15 6, 15 9, 12 9, 12 6, 15 6))>]
# number of tile in the bbox: 1
# number of tile overlapping in the polygon: 1
# ['012E_06N']
# extract points in 3.36 s
# number of points extracted: 1470442
# refine points in 2.80 s
# number of points refined: 555509
# total time in 6.16 s
# [<POLYGON ((15 6, 15 9, 12 9, 12 6, 15 6))>, <POLYGON ((18 6, 18 9, 15 9, 15 6, 18 6))>, <POLYGON ((15 9, 15 12, 12 12, 12 9, 15 9))>, <POLYGON ((18 9, 18 12, 15 12, 15 9, 18 9))>]
# number of tile in the bbox: 4
# number of tile overlapping in the polygon: 4
# ['012E_06N', '015E_06N', '012E_09N', '015E_09N']
# extract points in 9.85 s
# number of points extracted: 5441920
# refine points in 5.42 s
# number of points refined: 385606
# total time in 15.27 s
# [<POLYGON ((15 6, 15 9, 12 9, 12 6, 15 6))>, <POLYGON ((18 6, 18 9, 15 9, 15 6, 18 6))>, <POLYGON ((15 9, 15 12, 12 12, 12 9, 15 9))>, <POLYGON ((18 9, 18 12, 15 12, 15 9, 18 9))>]
# number of tile in the bbox: 4
# number of tile overlapping in the polygon: 3
# ['012E_06N', '015E_06N', '012E_09N']
# extract points in 7.20 s
# number of points extracted: 4073343
# refine points in 4.42 s
# number of points refined: 462645
# total time in 11.62 s
# [<POLYGON ((15 6, 15 9, 12 9, 12 6, 15 6))>, <POLYGON ((18 6, 18 9, 15 9, 15 6, 18 6))>, <POLYGON ((15 9, 15 12, 12 12, 12 9, 15 9))>, <POLYGON ((18 9, 18 12, 15 12, 15 9, 18 9))>]
# number of tile in the bbox: 4
# number of tile overlapping in the polygon: 4
# ['012E_06N', '015E_06N', '012E_09N', '015E_09N']
# extract points in 8.66 s
# number of points extracted: 5441920
# refine points in 5.52 s
# number of points refined: 320960
# total time in 14.17 s
# [<POLYGON ((12 3, 12 6, 9 6, 9 3, 12 3))>, <POLYGON ((15 3, 15 6, 12 6, 12 3, 15 3))>, <POLYGON ((12 6, 12 9, 9 9, 9 6, 12 6))>, <POLYGON ((15 6, 15 9, 12 9, 12 6, 15 6))>]
# number of tile in the bbox: 4
# number of tile overlapping in the polygon: 4
# ['009E_03N', '012E_03N', '009E_06N', '012E_06N']
# extract points in 3.46 s
# number of points extracted: 1470442
# refine points in 1.77 s
# number of points refined: 275311
# total time in 5.24 s
# [<POLYGON ((15 6, 15 9, 12 9, 12 6, 15 6))>, <POLYGON ((18 6, 18 9, 15 9, 15 6, 18 6))>, <POLYGON ((15 9, 15 12, 12 12, 12 9, 15 9))>, <POLYGON ((18 9, 18 12, 15 12, 15 9, 18 9))>]
# number of tile in the bbox: 4
# number of tile overlapping in the polygon: 4
# ['012E_06N', '015E_06N', '012E_09N', '015E_09N']
# extract points in 9.69 s
# number of points extracted: 5441920
# refine points in 5.17 s
# number of points refined: 342417
# total time in 14.86 s
# [<POLYGON ((18 9, 18 12, 15 12, 15 9, 18 9))>]
# number of tile in the bbox: 1
# number of tile overlapping in the polygon: 1
# ['015E_09N']
# extract points in 3.42 s
# number of points extracted: 1368577
# refine points in 2.45 s
# number of points refined: 483855
# total time in 5.87 s
# [<POLYGON ((15 9, 15 12, 12 12, 12 9, 15 9))>, <POLYGON ((18 9, 18 12, 15 12, 15 9, 18 9))>, <POLYGON ((15 12, 15 15, 12 15, 12 12, 15 12))>, <POLYGON ((18 12, 18 15, 15 15, 15 12, 18 12))>]
# number of tile in the bbox: 4
# number of tile overlapping in the polygon: 4
# ['012E_09N', '015E_09N', '012E_12N', '015E_12N']
# extract points in 4.27 s
# number of points extracted: 2531113
# refine points in 2.87 s
# number of points refined: 339957
# total time in 7.14 s
# [<POLYGON ((15 3, 15 6, 12 6, 12 3, 15 3))>, <POLYGON ((18 3, 18 6, 15 6, 15 3, 18 3))>, <POLYGON ((15 6, 15 9, 12 9, 12 6, 15 6))>, <POLYGON ((18 6, 18 9, 15 9, 15 6, 18 6))>]
# number of tile in the bbox: 4
# number of tile overlapping in the polygon: 4
# ['012E_03N', '015E_03N', '012E_06N', '015E_06N']
# extract points in 4.81 s
# number of points extracted: 2910807
# refine points in 4.17 s
# number of points refined: 645377
# total time in 8.98 s
# [<POLYGON ((18 6, 18 9, 15 9, 15 6, 18 6))>, <POLYGON ((18 9, 18 12, 15 12, 15 9, 18 9))>]
# number of tile in the bbox: 2
# number of tile overlapping in the polygon: 2
# ['015E_06N', '015E_09N']
# extract points in 6.41 s
# number of points extracted: 2808942
# refine points in 3.52 s
# number of points refined: 450588
# total time in 9.93 s
# [<POLYGON ((12 9, 12 12, 9 12, 9 9, 12 9))>, <POLYGON ((15 9, 15 12, 12 12, 12 9, 15 9))>, <POLYGON ((12 12, 12 15, 9 15, 9 12, 12 12))>, <POLYGON ((15 12, 15 15, 12 15, 12 12, 15 12))>]
# number of tile in the bbox: 4
# number of tile overlapping in the polygon: 4
# ['009E_09N', '012E_09N', '009E_12N', '012E_12N']
# extract points in 2.56 s
# number of points extracted: 1162536
# refine points in 1.45 s
# number of points refined: 229384
# total time in 4.02 s
# [<POLYGON ((18 6, 18 9, 15 9, 15 6, 18 6))>, <POLYGON ((18 9, 18 12, 15 12, 15 9, 18 9))>]
# number of tile in the bbox: 2
# number of tile overlapping in the polygon: 2
# ['015E_06N', '015E_09N']
# extract points in 5.30 s
# number of points extracted: 2808942
# refine points in 3.22 s
# number of points refined: 389261
# total time in 8.53 s
# [<POLYGON ((15 9, 15 12, 12 12, 12 9, 15 9))>, <POLYGON ((18 9, 18 12, 15 12, 15 9, 18 9))>, <POLYGON ((15 12, 15 15, 12 15, 12 12, 15 12))>, <POLYGON ((18 12, 18 15, 15 15, 15 12, 18 12))>]
# number of tile in the bbox: 4
# number of tile overlapping in the polygon: 4
# ['012E_09N', '015E_09N', '012E_12N', '015E_12N']
# extract points in 3.99 s
# number of points extracted: 2531113
# refine points in 2.80 s
# number of points refined: 333937
# total time in 6.79 s
# [<POLYGON ((15 6, 15 9, 12 9, 12 6, 15 6))>, <POLYGON ((18 6, 18 9, 15 9, 15 6, 18 6))>, <POLYGON ((15 9, 15 12, 12 12, 12 9, 15 9))>, <POLYGON ((18 9, 18 12, 15 12, 15 9, 18 9))>]
# number of tile in the bbox: 4
# number of tile overlapping in the polygon: 4
# ['012E_06N', '015E_06N', '012E_09N', '015E_09N']
# extract points in 9.23 s
# number of points extracted: 5441920
# refine points in 5.51 s
# number of points refined: 412810
# total time in 14.75 s
# [<POLYGON ((15 9, 15 12, 12 12, 12 9, 15 9))>, <POLYGON ((18 9, 18 12, 15 12, 15 9, 18 9))>, <POLYGON ((15 12, 15 15, 12 15, 12 12, 15 12))>, <POLYGON ((18 12, 18 15, 15 15, 15 12, 18 12))>]
# number of tile in the bbox: 4
# number of tile overlapping in the polygon: 4
# ['012E_09N', '015E_09N', '012E_12N', '015E_12N']
# extract points in 4.16 s
# number of points extracted: 2531113
# refine points in 2.24 s
# number of points refined: 172718
# total time in 6.40 s
# [<POLYGON ((18 9, 18 12, 15 12, 15 9, 18 9))>, <POLYGON ((21 9, 21 12, 18 12, 18 9, 21 9))>]
# number of tile in the bbox: 2
# number of tile overlapping in the polygon: 2
# ['015E_09N', '018E_09N']
# extract points in 2.34 s
# number of points extracted: 1368577
# refine points in 2.39 s
# number of points refined: 488323
# total time in 4.73 s
# [<POLYGON ((18 6, 18 9, 15 9, 15 6, 18 6))>, <POLYGON ((18 9, 18 12, 15 12, 15 9, 18 9))>]
# number of tile in the bbox: 2
# number of tile overlapping in the polygon: 2
# ['015E_06N', '015E_09N']
# extract points in 4.29 s
# number of points extracted: 2808942
# refine points in 3.28 s
# number of points refined: 416107
# total time in 7.57 s
# [<POLYGON ((15 6, 15 9, 12 9, 12 6, 15 6))>, <POLYGON ((18 6, 18 9, 15 9, 15 6, 18 6))>, <POLYGON ((15 9, 15 12, 12 12, 12 9, 15 9))>, <POLYGON ((18 9, 18 12, 15 12, 15 9, 18 9))>]
# number of tile in the bbox: 4
# number of tile overlapping in the polygon: 4
# ['012E_06N', '015E_06N', '012E_09N', '015E_09N']
# extract points in 10.07 s
# number of points extracted: 5441920
# refine points in 5.14 s
# number of points refined: 335080
# total time in 15.21 s
# [<POLYGON ((15 3, 15 6, 12 6, 12 3, 15 3))>, <POLYGON ((18 3, 18 6, 15 6, 15 3, 18 3))>, <POLYGON ((15 6, 15 9, 12 9, 12 6, 15 6))>, <POLYGON ((18 6, 18 9, 15 9, 15 6, 18 6))>]
# number of tile in the bbox: 4
# number of tile overlapping in the polygon: 4
# ['012E_03N', '015E_03N', '012E_06N', '015E_06N']
# extract points in 5.94 s
# number of points extracted: 2910807
# refine points in 4.12 s
# number of points refined: 659846
# total time in 10.07 s
# [<POLYGON ((18 9, 18 12, 15 12, 15 9, 18 9))>, <POLYGON ((18 12, 18 15, 15 15, 15 12, 18 12))>]
# number of tile in the bbox: 2
# number of tile overlapping in the polygon: 2
# ['015E_09N', '015E_12N']
# extract points in 3.45 s
# number of points extracted: 1368577
# refine points in 1.97 s
# number of points refined: 349726
# total time in 5.43 s
# [<POLYGON ((15 3, 15 6, 12 6, 12 3, 15 3))>, <POLYGON ((18 3, 18 6, 15 6, 15 3, 18 3))>, <POLYGON ((15 6, 15 9, 12 9, 12 6, 15 6))>, <POLYGON ((18 6, 18 9, 15 9, 15 6, 18 6))>]
# number of tile in the bbox: 4
# number of tile overlapping in the polygon: 4
# ['012E_03N', '015E_03N', '012E_06N', '015E_06N']
# extract points in 7.72 s
# number of points extracted: 2910807
# refine points in 4.18 s
# number of points refined: 662026
# total time in 11.90 s

# %%
ext_times_6=[]
refine_times_6=[]
total_times_6=[]
for i in range(30):
    rand_point = Point(random.uniform(12,18),random.uniform(6,12))
    geometry = rand_point.buffer(1)
    ext_time, refine_time, total_time = timer(geometry,partition='6degree_tile')
    ext_times_6.append(ext_time)
    refine_times_6.append(refine_time)
    total_times_6.append(total_time)
# Out:
# [<POLYGON ((18 0, 18 6, 12 6, 12 0, 18 0))>, <POLYGON ((18 6, 18 12, 12 12, 12 6, 18 6))>]
# number of tile in the bbox: 2
# number of tile overlapping in the polygon: 2
# ['012E_00N', '012E_06N']
# extract points in 17.37 s
# number of points extracted: 5441920
# refine points in 5.68 s
# number of points refined: 525046
# total time in 23.05 s
# [<POLYGON ((18 6, 18 12, 12 12, 12 6, 18 6))>]
# number of tile in the bbox: 1
# number of tile overlapping in the polygon: 1
# ['012E_06N']
# extract points in 23.45 s
# number of points extracted: 5441920
# refine points in 5.52 s
# number of points refined: 374530
# total time in 28.97 s
# [<POLYGON ((12 6, 12 12, 6 12, 6 6, 12 6))>, <POLYGON ((18 6, 18 12, 12 12, 12 6, 18 6))>]
# number of tile in the bbox: 2
# number of tile overlapping in the polygon: 2
# ['006E_06N', '012E_06N']
# extract points in 15.63 s
# number of points extracted: 5441920
# refine points in 5.20 s
# number of points refined: 356843
# total time in 20.83 s
# [<POLYGON ((12 6, 12 12, 6 12, 6 6, 12 6))>, <POLYGON ((18 6, 18 12, 12 12, 12 6, 18 6))>]
# number of tile in the bbox: 2
# number of tile overlapping in the polygon: 2
# ['006E_06N', '012E_06N']
# extract points in 15.42 s
# number of points extracted: 5441920
# refine points in 5.68 s
# number of points refined: 484781
# total time in 21.10 s
# [<POLYGON ((18 6, 18 12, 12 12, 12 6, 18 6))>]
# number of tile in the bbox: 1
# number of tile overlapping in the polygon: 1
# ['012E_06N']
# extract points in 14.55 s
# number of points extracted: 5441920
# refine points in 5.79 s
# number of points refined: 484965
# total time in 20.34 s
# [<POLYGON ((12 6, 12 12, 6 12, 6 6, 12 6))>, <POLYGON ((18 6, 18 12, 12 12, 12 6, 18 6))>]
# number of tile in the bbox: 2
# number of tile overlapping in the polygon: 2
# ['006E_06N', '012E_06N']
# extract points in 16.61 s
# number of points extracted: 5441920
# refine points in 5.40 s
# number of points refined: 350823
# total time in 22.02 s
# [<POLYGON ((18 0, 18 6, 12 6, 12 0, 18 0))>, <POLYGON ((18 6, 18 12, 12 12, 12 6, 18 6))>]
# number of tile in the bbox: 2
# number of tile overlapping in the polygon: 2
# ['012E_00N', '012E_06N']
# extract points in 17.91 s
# number of points extracted: 5441920
# refine points in 5.33 s
# number of points refined: 342926
# total time in 23.25 s
# [<POLYGON ((18 6, 18 12, 12 12, 12 6, 18 6))>]
# number of tile in the bbox: 1
# number of tile overlapping in the polygon: 1
# ['012E_06N']
# extract points in 16.36 s
# number of points extracted: 5441920
# refine points in 5.97 s
# number of points refined: 540709
# total time in 22.33 s
# [<POLYGON ((12 0, 12 6, 6 6, 6 0, 12 0))>, <POLYGON ((18 0, 18 6, 12 6, 12 0, 18 0))>, <POLYGON ((12 6, 12 12, 6 12, 6 6, 12 6))>, <POLYGON ((18 6, 18 12, 12 12, 12 6, 18 6))>]
# number of tile in the bbox: 4
# number of tile overlapping in the polygon: 4
# ['006E_00N', '012E_00N', '006E_06N', '012E_06N']
# extract points in 26.57 s
# number of points extracted: 5441920
# refine points in 4.74 s
# number of points refined: 214005
# total time in 31.31 s
# [<POLYGON ((18 6, 18 12, 12 12, 12 6, 18 6))>]
# number of tile in the bbox: 1
# number of tile overlapping in the polygon: 1
# ['012E_06N']
# extract points in 48.90 s
# number of points extracted: 5441920
# refine points in 6.36 s
# number of points refined: 700356
# total time in 55.26 s
# [<POLYGON ((18 6, 18 12, 12 12, 12 6, 18 6))>]
# number of tile in the bbox: 1
# number of tile overlapping in the polygon: 1
# ['012E_06N']
# extract points in 43.70 s
# number of points extracted: 5441920
# refine points in 5.05 s
# number of points refined: 336738
# total time in 48.76 s
# [<POLYGON ((18 6, 18 12, 12 12, 12 6, 18 6))>]
# number of tile in the bbox: 1
# number of tile overlapping in the polygon: 1
# ['012E_06N']
# extract points in 42.96 s
# number of points extracted: 5441920
# refine points in 5.03 s
# number of points refined: 341463
# total time in 47.99 s
# [<POLYGON ((18 6, 18 12, 12 12, 12 6, 18 6))>, <POLYGON ((18 12, 18 18, 12 18, 12 12, 18 12))>]
# number of tile in the bbox: 2
# number of tile overlapping in the polygon: 2
# ['012E_06N', '012E_12N']
# extract points in 23.65 s
# number of points extracted: 5441920
# refine points in 4.75 s
# number of points refined: 267467
# total time in 28.41 s
# [<POLYGON ((18 6, 18 12, 12 12, 12 6, 18 6))>]
# number of tile in the bbox: 1
# number of tile overlapping in the polygon: 1
# ['012E_06N']
# extract points in 20.93 s
# number of points extracted: 5441920
# refine points in 5.34 s
# number of points refined: 402033
# total time in 26.26 s
# [<POLYGON ((18 6, 18 12, 12 12, 12 6, 18 6))>]
# number of tile in the bbox: 1
# number of tile overlapping in the polygon: 1
# ['012E_06N']
# extract points in 16.53 s
# number of points extracted: 5441920
# refine points in 5.34 s
# number of points refined: 397902
# total time in 21.88 s
# [<POLYGON ((18 6, 18 12, 12 12, 12 6, 18 6))>, <POLYGON ((24 6, 24 12, 18 12, 18 6, 24 6))>]
# number of tile in the bbox: 2
# number of tile overlapping in the polygon: 2
# ['012E_06N', '018E_06N']
# extract points in 14.84 s
# number of points extracted: 5441920
# refine points in 5.53 s
# number of points refined: 429347
# total time in 20.38 s
# [<POLYGON ((18 0, 18 6, 12 6, 12 0, 18 0))>, <POLYGON ((18 6, 18 12, 12 12, 12 6, 18 6))>]
# number of tile in the bbox: 2
# number of tile overlapping in the polygon: 2
# ['012E_00N', '012E_06N']
# extract points in 15.78 s
# number of points extracted: 5441920
# refine points in 6.84 s
# number of points refined: 649419
# total time in 22.62 s
# [<POLYGON ((12 6, 12 12, 6 12, 6 6, 12 6))>, <POLYGON ((18 6, 18 12, 12 12, 12 6, 18 6))>]
# number of tile in the bbox: 2
# number of tile overlapping in the polygon: 2
# ['006E_06N', '012E_06N']
# extract points in 18.00 s
# number of points extracted: 5441920
# refine points in 5.39 s
# number of points refined: 437560
# total time in 23.39 s
# [<POLYGON ((18 6, 18 12, 12 12, 12 6, 18 6))>]
# number of tile in the bbox: 1
# number of tile overlapping in the polygon: 1
# ['012E_06N']
# extract points in 13.82 s
# number of points extracted: 5441920
# refine points in 5.58 s
# number of points refined: 372843
# total time in 19.40 s
# [<POLYGON ((18 0, 18 6, 12 6, 12 0, 18 0))>, <POLYGON ((18 6, 18 12, 12 12, 12 6, 18 6))>]
# number of tile in the bbox: 2
# number of tile overlapping in the polygon: 2
# ['012E_00N', '012E_06N']
# extract points in 15.26 s
# number of points extracted: 5441920
# refine points in 6.19 s
# number of points refined: 646916
# total time in 21.45 s
# [<POLYGON ((12 6, 12 12, 6 12, 6 6, 12 6))>, <POLYGON ((18 6, 18 12, 12 12, 12 6, 18 6))>]
# number of tile in the bbox: 2
# number of tile overlapping in the polygon: 2
# ['006E_06N', '012E_06N']
# extract points in 15.21 s
# number of points extracted: 5441920
# refine points in 5.34 s
# number of points refined: 406953
# total time in 20.55 s
# [<POLYGON ((18 6, 18 12, 12 12, 12 6, 18 6))>]
# number of tile in the bbox: 1
# number of tile overlapping in the polygon: 1
# ['012E_06N']
# extract points in 14.66 s
# number of points extracted: 5441920
# refine points in 5.65 s
# number of points refined: 421105
# total time in 20.32 s
# [<POLYGON ((18 6, 18 12, 12 12, 12 6, 18 6))>]
# number of tile in the bbox: 1
# number of tile overlapping in the polygon: 1
# ['012E_06N']
# extract points in 18.83 s
# number of points extracted: 5441920
# refine points in 5.77 s
# number of points refined: 474798
# total time in 24.60 s
# [<POLYGON ((12 0, 12 6, 6 6, 6 0, 12 0))>, <POLYGON ((18 0, 18 6, 12 6, 12 0, 18 0))>, <POLYGON ((12 6, 12 12, 6 12, 6 6, 12 6))>, <POLYGON ((18 6, 18 12, 12 12, 12 6, 18 6))>]
# number of tile in the bbox: 4
# number of tile overlapping in the polygon: 4
# ['006E_00N', '012E_00N', '006E_06N', '012E_06N']
# extract points in 14.45 s
# number of points extracted: 5441920
# refine points in 4.75 s
# number of points refined: 274260
# total time in 19.21 s
# [<POLYGON ((18 6, 18 12, 12 12, 12 6, 18 6))>]
# number of tile in the bbox: 1
# number of tile overlapping in the polygon: 1
# ['012E_06N']
# extract points in 14.79 s
# number of points extracted: 5441920
# refine points in 5.24 s
# number of points refined: 343154
# total time in 20.04 s
# [<POLYGON ((18 6, 18 12, 12 12, 12 6, 18 6))>]
# number of tile in the bbox: 1
# number of tile overlapping in the polygon: 1
# ['012E_06N']
# extract points in 24.93 s
# number of points extracted: 5441920
# refine points in 6.36 s
# number of points refined: 576055
# total time in 31.30 s
# [<POLYGON ((18 0, 18 6, 12 6, 12 0, 18 0))>, <POLYGON ((18 6, 18 12, 12 12, 12 6, 18 6))>]
# number of tile in the bbox: 2
# number of tile overlapping in the polygon: 2
# ['012E_00N', '012E_06N']
# extract points in 21.03 s
# number of points extracted: 5441920
# refine points in 4.93 s
# number of points refined: 247001
# total time in 25.96 s
# [<POLYGON ((18 6, 18 12, 12 12, 12 6, 18 6))>]
# number of tile in the bbox: 1
# number of tile overlapping in the polygon: 1
# ['012E_06N']
# extract points in 15.35 s
# number of points extracted: 5441920
# refine points in 5.42 s
# number of points refined: 337202
# total time in 20.78 s
# [<POLYGON ((18 6, 18 12, 12 12, 12 6, 18 6))>]
# number of tile in the bbox: 1
# number of tile overlapping in the polygon: 1
# ['012E_06N']
# extract points in 22.07 s
# number of points extracted: 5441920
# refine points in 6.00 s
# number of points refined: 505695
# total time in 28.07 s
# [<POLYGON ((18 6, 18 12, 12 12, 12 6, 18 6))>, <POLYGON ((24 6, 24 12, 18 12, 18 6, 24 6))>]
# number of tile in the bbox: 2
# number of tile overlapping in the polygon: 2
# ['012E_06N', '018E_06N']
# extract points in 19.05 s
# number of points extracted: 5441920
# refine points in 5.75 s
# number of points refined: 441754
# total time in 24.79 s

# %%
import matplotlib.pyplot as plt
import numpy as np
  
fig = plt.figure(figsize =(10, 7))
ax = fig.add_subplot(111)

data = [ext_times_1,ext_times_3,ext_times_6]

# x-axis labels
ax.set_xticklabels(['1x1 degree tile','3x3 degree tile','6x6 degree tile'])
# Creating plot
plt.boxplot(data)


plt.title("Extract points time")
ax.set_ylabel('processing time')

# show plot
plt.show()
# Out:
# /tmp/ipykernel_11847/2338193712.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['1x1 degree tile','3x3 degree tile','6x6 degree tile'])

# %%
import matplotlib.pyplot as plt
import numpy as np
  
fig = plt.figure(figsize =(10, 7))
ax = fig.add_subplot(111)

data = [refine_times_1,refine_times_3,refine_times_6]

# x-axis labels
ax.set_xticklabels(['1x1 degree tile','3x3 degree tile','6x6 degree tile'])
# Creating plot
plt.boxplot(data)


plt.title("Refine points time")
ax.set_ylabel('processing time')

# show plot
plt.show()
# Out:
# /tmp/ipykernel_11847/3205182063.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['1x1 degree tile','3x3 degree tile','6x6 degree tile'])
